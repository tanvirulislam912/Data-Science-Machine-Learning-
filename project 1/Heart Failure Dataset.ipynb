# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Heart Disease.csv")

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
df.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.isnull()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              False  False    False            False   False           False
# 1              False  False    False            False   False           False
# 2              False  False    False            False   False           False
# 3              False  False    False            False   False           False
# 4              False  False    False            False   False           False
# ...              ...    ...      ...              ...     ...             ...
# 319790         False  False    False            False   False           False
# 319791         False  False    False            False   False           False
# 319792         False  False    False            False   False           False
# 319793         False  False    False            False   False           False
# 319794         False  False    False            False   False           False
#
#         MentalHealth  DiffWalking    Sex  AgeCategory   Race  Diabetic  \
# 0              False        False  False        False  False     False
# 1              False        False  False        False  False     False
# 2              False        False  False        False  False     False
# 3              False        False  False        False  False     False
# 4              False        False  False        False  False     False
# ...              ...          ...    ...          ...    ...       ...
# 319790         False        False  False        False  False     False
# 319791         False        False  False        False  False     False
# 319792         False        False  False        False  False     False
# 319793         False        False  False        False  False     False
# 319794         False        False  False        False  False     False
#
#         PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 0                  False      False      False   False          False
# 1                  False      False      False   False          False
# 2                  False      False      False   False          False
# 3                  False      False      False   False          False
# 4                  False      False      False   False          False
# ...                  ...        ...        ...     ...            ...
# 319790             False      False      False   False          False
# 319791             False      False      False   False          False
# 319792             False      False      False   False          False
# 319793             False      False      False   False          False
# 319794             False      False      False   False          False
#
#         SkinCancer
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 319790       False
# 319791       False
# 319792       False
# 319793       False
# 319794       False
#
# [319795 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.isnull().sum().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Basic Data Analysis

# %%
df.BMI.value_counts()
# Out:
# 26.63    3762
# 27.46    2767
# 27.44    2723
# 24.41    2696
# 27.12    2525
#          ...
# 59.85       1
# 50.59       1
# 92.53       1
# 62.95       1
# 46.56       1
# Name: BMI, Length: 3604, dtype: int64

# %%
df.PhysicalHealth.value_counts()
# Out:
# 0.0     226589
# 30.0     19509
# 2.0      14880
# 1.0      10489
# 3.0       8617
# 5.0       7606
# 10.0      5453
# 15.0      5012
# 7.0       4629
# 4.0       4468
# 20.0      3216
# 14.0      2893
# 6.0       1270
# 25.0      1164
# 8.0        924
# 21.0       626
# 12.0       605
# 28.0       446
# 29.0       204
# 9.0        180
# 18.0       167
# 16.0       135
# 27.0       124
# 17.0       110
# 13.0        91
# 22.0        89
# 11.0        85
# 24.0        67
# 26.0        66
# 23.0        46
# 19.0        35
# Name: PhysicalHealth, dtype: int64

# %%
df.MentalHealth.value_counts()
# Out:
# 0.0     205401
# 30.0     17373
# 2.0      16495
# 5.0      14149
# 10.0     10513
# 3.0      10466
# 15.0      9896
# 1.0       9291
# 7.0       5528
# 20.0      5431
# 4.0       5379
# 14.0      2048
# 25.0      1954
# 6.0       1510
# 8.0       1094
# 12.0       757
# 28.0       515
# 21.0       352
# 29.0       317
# 18.0       211
# 9.0        203
# 16.0       152
# 17.0       128
# 27.0       126
# 13.0       110
# 22.0        98
# 11.0        83
# 23.0        68
# 24.0        67
# 26.0        59
# 19.0        21
# Name: MentalHealth, dtype: int64

# %%
df.AgeCategory.value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
df.GenHealth.value_counts()
# Out:
# Very good    113858
# Good          93129
# Excellent     66842
# Fair          34677
# Poor          11289
# Name: GenHealth, dtype: int64

# %%
df.SleepTime.value_counts()
# Out:
# 7.0     97751
# 8.0     97602
# 6.0     66721
# 5.0     19184
# 9.0     16041
# 10.0     7796
# 4.0      7750
# 12.0     2205
# 3.0      1992
# 2.0       788
# 1.0       551
# 11.0      415
# 14.0      243
# 16.0      236
# 15.0      189
# 18.0      102
# 13.0       97
# 20.0       64
# 24.0       30
# 17.0       21
# 22.0        9
# 19.0        3
# 23.0        3
# 21.0        2
# Name: SleepTime, dtype: int64

# %%
df.Race.value_counts()
# Out:
# White                             245212
# Hispanic                           27446
# Black                              22939
# Other                              10928
# Asian                               8068
# American Indian/Alaskan Native      5202
# Name: Race, dtype: int64

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
raceVal = df.Race.value_counts().values

# %%
print(raceVal)
# Out:
# [245212  27446  22939  10928   8068   5202]

# %%
raceName = df.Race.value_counts().index

# %%
print(raceName)
# Out:
# Index(['White', 'Hispanic', 'Black', 'Other', 'Asian',
#        'American Indian/Alaskan Native'],
#       dtype='object')

# %%
strokValue = df.Stroke.value_counts().values
strokeName = df.Stroke.value_counts().index

print(strokValue)
print(strokeName)
# Out:
# [307726  12069]
# Index(['No', 'Yes'], dtype='object')

# %%
plt.pie(strokValue, labels=strokeName, radius=1.5, autopct= "%1.5f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1956fb6ed60>,
#   <matplotlib.patches.Wedge at 0x1956fb7b4c0>],
#  [Text(-1.6384163778635836, 0.19517113707814338, 'No'),
#   Text(1.6384163710111173, -0.19517119460299742, 'Yes')],
#  [Text(-0.8936816606528636, 0.10645698386080546, '96.22602%'),
#   Text(0.8936816569151548, -0.10645701523799858, '3.77398%')])

# %%
RaceValue = df.Race.value_counts().values
RaceName = df.Race.value_counts().index
plt.pie(RaceValue, labels=RaceName, radius=1.5, autopct= "%1.5f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1956fbc8a60>,
#   <matplotlib.patches.Wedge at 0x1956fbd71f0>,
#   <matplotlib.patches.Wedge at 0x1956fbd77f0>,
#   <matplotlib.patches.Wedge at 0x1956fbd7f10>,
#   <matplotlib.patches.Wedge at 0x1956fbe5670>,
#   <matplotlib.patches.Wedge at 0x1956fbe5dc0>],
#  [Text(-1.2265775024121168, 1.1036338299347541, 'White'),
#   Text(0.6044217210930803, -1.5353092141555327, 'Hispanic'),
#   Text(1.2611614771067587, -1.0639416002121072, 'Black'),
#   Text(1.5394846142002692, -0.5937062595599353, 'Other'),
#   Text(1.6229076689791129, -0.2977762548773535, 'Asian'),
#   Text(1.6478459415277453, -0.08428376469130167, 'American Indian/Alaskan Native')],
#  [Text(-0.6690422740429727, 0.6019820890553204, '76.67787%'),
#   Text(0.3296845751416801, -0.8374413895393813, '8.58237%'),
#   Text(0.6879062602400501, -0.5803317819338765, '7.17303%'),
#   Text(0.8397188804728739, -0.32383977794178287, '3.41719%'),
#   Text(0.8852223648976978, -0.1624234117512837, '2.52287%'),
#   Text(0.8988250590151337, -0.04597296255889181, '1.62667%')])

# %%
AgeValue = df.AgeCategory.value_counts().values
AgeName = df.AgeCategory.value_counts().index
plt.pie(AgeValue, labels=AgeName, radius=1.5, autopct="%1.5f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1956fc3d100>,
#   <matplotlib.patches.Wedge at 0x1956fc3d610>,
#   <matplotlib.patches.Wedge at 0x1956fc3dd30>,
#   <matplotlib.patches.Wedge at 0x1956fc474c0>,
#   <matplotlib.patches.Wedge at 0x1956fc47be0>,
#   <matplotlib.patches.Wedge at 0x1956fc56340>,
#   <matplotlib.patches.Wedge at 0x1956fc56a60>,
#   <matplotlib.patches.Wedge at 0x1956fc631c0>,
#   <matplotlib.patches.Wedge at 0x1956fc638e0>,
#   <matplotlib.patches.Wedge at 0x1956fc6f040>,
#   <matplotlib.patches.Wedge at 0x1956fc3d0d0>,
#   <matplotlib.patches.Wedge at 0x1956fc6fe50>,
#   <matplotlib.patches.Wedge at 0x1956fc7f5b0>],
#  [Text(1.5580101511490057, 0.5432350954390307, '65-69'),
#   Text(0.8888498503848542, 1.3901244345276513, '60-64'),
#   Text(-0.11081197359359493, 1.6462747967785611, '70-74'),
#   Text(-1.0177719244398358, 1.2987071686188667, '55-59'),
#   Text(-1.5416498225519781, 0.5880610721901718, '50-54'),
#   Text(-1.6376941753278647, -0.2011412143176681, '80 or older'),
#   Text(-1.3859660453062637, -0.8953201222233957, '45-49'),
#   Text(-0.8933653516245847, -1.3872268554626106, '75-79'),
#   Text(-0.25338889103321294, -1.6304275727247006, '18-24'),
#   Text(0.4227586187032748, -1.594921675290702, '40-44'),
#   Text(1.021187578771048, -1.2960231205359438, '35-39'),
#   Text(1.434069882742753, -0.8160536571881698, '30-34'),
#   Text(1.627164973200275, -0.2735583118644882, '25-29')],
#  [Text(0.8498237188085485, 0.29631005205765304, '10.67903%'),
#   Text(0.4848271911190113, 0.758249691560537, '10.53362%'),
#   Text(-0.060442894687415406, 0.8979680709701241, '9.71404%'),
#   Text(-0.5551483224217285, 0.7083857283375635, '9.30502%'),
#   Text(-0.8408999032101698, 0.3207605848310027, '7.93696%'),
#   Text(-0.8932877319970169, -0.10971338962781894, '7.55265%'),
#   Text(-0.7559814792579619, -0.4883564303036703, '6.81405%'),
#   Text(-0.4872901917952279, -0.7566691938886966, '6.71743%'),
#   Text(-0.1382121223817525, -0.8893241305771092, '6.58672%'),
#   Text(0.2305956102017862, -0.8699572774312919, '6.56858%'),
#   Text(0.5570114066023897, -0.7069217021105146, '6.42599%'),
#   Text(0.7822199360415015, -0.44512017664809256, '5.86407%'),
#   Text(0.8875445308365135, -0.1492136246533572, '5.30183%')])

# %%
DiffWalkingValue = df.DiffWalking.value_counts().values
DiffWalkingName = df.DiffWalking.value_counts().index
plt.pie(DiffWalkingValue, labels=DiffWalkingName, radius=1.5, autopct="%1.5f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x19570c6a970>,
#   <matplotlib.patches.Wedge at 0x19570c7b070>],
#  [Text(-1.4954487017123157, 0.69723251541143, 'No'),
#   Text(1.4954486364326893, -0.69723265542544, 'Yes')],
#  [Text(-0.8156992918430811, 0.38030864476987086, '86.11298%'),
#   Text(0.8156992562360122, -0.38030872114114905, '13.88702%')])

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
df.BMI.value_counts()
# Out:
# 26.63    3762
# 27.46    2767
# 27.44    2723
# 24.41    2696
# 27.12    2525
#          ...
# 59.85       1
# 50.59       1
# 92.53       1
# 62.95       1
# 46.56       1
# Name: BMI, Length: 3604, dtype: int64

# %%
sns.countplot(x='BMI', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='count'>

# %%
plt.scatter(x=df.BMI, y=df.HeartDisease)

# %%
df.Smoking.value_counts()
# Out:
# No     187887
# Yes    131908
# Name: Smoking, dtype: int64

# %%
sns.countplot(x='Smoking', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Smoking', ylabel='count'>

# %%
plt.scatter(x=df.Smoking, y=df.HeartDisease)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.AlcoholDrinking.value_counts()
# Out:
# No     298018
# Yes     21777
# Name: AlcoholDrinking, dtype: int64

# %%
sns.countplot(x='AlcoholDrinking', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='AlcoholDrinking', ylabel='count'>

# %%
plt.scatter(x=df.AlcoholDrinking, y=df.HeartDisease)

# %%
df.Stroke.value_counts()
# Out:
# No     307726
# Yes     12069
# Name: Stroke, dtype: int64

# %%
sns.countplot(x='Stroke', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Stroke', ylabel='count'>

# %%
plt.scatter(x=df.Stroke, y=df.HeartDisease)

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df.PhysicalHealth, data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='PhysicalHealth', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df.MentalHealth, data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='MentalHealth', ylabel='count'>

# %%
sns.countplot(x=df.DiffWalking, data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='DiffWalking', ylabel='count'>

# %%
df.Sex.value_counts()
# Out:
# Female    167805
# Male      151990
# Name: Sex, dtype: int64

# %%
sns.countplot(x='Sex', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df.AgeCategory, data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='AgeCategory', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df.Race, data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %%
sns.countplot(x=df.SkinCancer, data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='SkinCancer', ylabel='count'>

# %%
df[['SkinCancer', 'HeartDisease']]. groupby(['SkinCancer', 'HeartDisease']). size().reset_index()
# Out:
#   SkinCancer HeartDisease       0
# 0         No           No  267583
# 1         No          Yes   22393
# 2        Yes           No   24839
# 3        Yes          Yes    4980

# %%
df[['KidneyDisease', 'HeartDisease']]. groupby(['KidneyDisease', 'HeartDisease']). size().reset_index()
# Out:
#   KidneyDisease HeartDisease       0
# 0            No           No  284098
# 1            No          Yes   23918
# 2           Yes           No    8324
# 3           Yes          Yes    3455

# %%
df[['Smoking', 'HeartDisease']]. groupby(['Smoking', 'HeartDisease']). size().reset_index()
# Out:
#   Smoking HeartDisease       0
# 0      No           No  176551
# 1      No          Yes   11336
# 2     Yes           No  115871
# 3     Yes          Yes   16037

# %%
df[['Stroke', 'HeartDisease']]. groupby(['Stroke', 'HeartDisease']). size().reset_index()
# Out:
#   Stroke HeartDisease       0
# 0     No           No  284742
# 1     No          Yes   22984
# 2    Yes           No    7680
# 3    Yes          Yes    4389

# %%
df[['DiffWalking', 'HeartDisease']]. groupby(['DiffWalking', 'HeartDisease']). size().reset_index()
# Out:
#   DiffWalking HeartDisease       0
# 0          No           No  258040
# 1          No          Yes   17345
# 2         Yes           No   34382
# 3         Yes          Yes   10028

# %%
sns.countplot(x=df.Smoking, data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Smoking', ylabel='count'>

# %%
sns.countplot(x='Diabetic', data=df, hue='HeartDisease')
# Out:
# <AxesSubplot:xlabel='Diabetic', ylabel='count'>

# %%
smoking_count = df[['Smoking', 'HeartDisease']].groupby(['Smoking', 'HeartDisease']).size().reset_index().rename(columns={0:'Smoking Count'})
smoking_count.head()
# Out:
#   Smoking HeartDisease  Smoking Count
# 0      No           No         176551
# 1      No          Yes          11336
# 2     Yes           No         115871
# 3     Yes          Yes          16037

# %%
sleepTime_count = df[['SleepTime', 'HeartDisease']].groupby(['SleepTime', 'HeartDisease']).size().reset_index().rename(columns={0:'SleepTime Count'})
sleepTime_count.head(10)
# Out:
#    SleepTime HeartDisease  SleepTime Count
# 0        1.0           No              491
# 1        1.0          Yes               60
# 2        2.0           No              660
# 3        2.0          Yes              128
# 4        3.0           No             1645
# 5        3.0          Yes              347
# 6        4.0           No             6570
# 7        4.0          Yes             1180
# 8        5.0           No            17154
# 9        5.0          Yes             2030

# %%
sleepTimeCount = sleepTime_count.sort_values(['SleepTime Count'], ascending=[False])
sleepTimeCount_top10 = sleepTimeCount.head(10)

# %%
sleepTimeCount_top10
# Out:
#     SleepTime HeartDisease  SleepTime Count
# 12        7.0           No            91426
# 14        8.0           No            89244
# 10        6.0           No            61294
# 8         5.0           No            17154
# 16        9.0           No            14345
# 15        8.0          Yes             8358
# 18       10.0           No             6631
# 6         4.0           No             6570
# 13        7.0          Yes             6325
# 11        6.0          Yes             5427

# %%
sns.barplot(x='SleepTime Count', y='SleepTime', data=sleepTimeCount_top10)
# Out:
# <AxesSubplot:xlabel='SleepTime Count', ylabel='SleepTime'>

# %%
sns.countplot(x='HeartDisease', data=sleepTimeCount_top10, hue='SleepTime Count')
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>

# %% [markdown]
# # Label Encoding

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in df.columns:
    if df[col].dtype == np.number:
        continue
    else:
        df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0          30.0            0    0            7     5         2
# 1           0.0            0    0           12     5         0
# 2          30.0            0    1            9     5         2
# 3           0.0            0    0           11     5         0
# 4           0.0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# 0                 1          4        5.0       1              0           1
# 1                 1          4        7.0       0              0           0
# 2                 1          1        8.0       1              0           0
# 3                 0          2        6.0       0              0           1
# 4                 1          4        8.0       0              0           0

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.HeartDisease.value_counts()
# Out:
# 0    292422
# 1     27373
# Name: HeartDisease, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#         HeartDisease            BMI        Smoking  AlcoholDrinking  \
# count  319795.000000  319795.000000  319795.000000    319795.000000
# mean        0.085595      28.325399       0.412477         0.068097
# std         0.279766       6.356100       0.492281         0.251912
# min         0.000000      12.020000       0.000000         0.000000
# 25%         0.000000      24.030000       0.000000         0.000000
# 50%         0.000000      27.340000       0.000000         0.000000
# 75%         0.000000      31.420000       1.000000         0.000000
# max         1.000000      94.850000       1.000000         1.000000
#
#               Stroke  PhysicalHealth   MentalHealth    DiffWalking  \
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean        0.037740         3.37171       3.898366       0.138870
# std         0.190567         7.95085       7.955235       0.345812
# min         0.000000         0.00000       0.000000       0.000000
# 25%         0.000000         0.00000       0.000000       0.000000
# 50%         0.000000         0.00000       0.000000       0.000000
# 75%         0.000000         2.00000       3.000000       0.000000
# max         1.000000        30.00000      30.000000       1.000000
#
#                  Sex    AgeCategory           Race       Diabetic  \
# count  319795.000000  319795.000000  319795.000000  319795.000000
# mean        0.475273       6.514536       4.396742       0.300386
# std         0.499389       3.564759       1.212208       0.716480
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       4.000000       5.000000       0.000000
# 50%         0.000000       7.000000       5.000000       0.000000
# 75%         1.000000       9.000000       5.000000       0.000000
# max         1.000000      12.000000       5.000000       3.000000
#
#        PhysicalActivity      GenHealth      SleepTime         Asthma  \
# count     319795.000000  319795.000000  319795.000000  319795.000000
# mean           0.775362       2.220904       7.097075       0.134061
# std            0.417344       1.534647       1.436007       0.340718
# min            0.000000       0.000000       1.000000       0.000000
# 25%            1.000000       1.000000       6.000000       0.000000
# 50%            1.000000       2.000000       7.000000       0.000000
# 75%            1.000000       4.000000       8.000000       0.000000
# max            1.000000       4.000000      24.000000       1.000000
#
#        KidneyDisease     SkinCancer
# count  319795.000000  319795.000000
# mean        0.036833       0.093244
# std         0.188352       0.290775
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max         1.000000       1.000000

# %%
df.corr()
# Out:
#                   HeartDisease       BMI   Smoking  AlcoholDrinking    Stroke  \
# HeartDisease          1.000000  0.051803  0.107764        -0.032080  0.196835
# BMI                   0.051803  1.000000  0.023118        -0.038816  0.019733
# Smoking               0.107764  0.023118  1.000000         0.111768  0.061226
# AlcoholDrinking      -0.032080 -0.038816  0.111768         1.000000 -0.019858
# Stroke                0.196835  0.019733  0.061226        -0.019858  1.000000
# PhysicalHealth        0.170721  0.109788  0.115352        -0.017254  0.137014
# MentalHealth          0.028591  0.064131  0.085157         0.051282  0.046467
# DiffWalking           0.201258  0.181678  0.120074        -0.035328  0.174143
# Sex                   0.070040  0.026940  0.085052         0.004200 -0.003091
# AgeCategory           0.233432 -0.004744  0.128331        -0.059528  0.137822
# Race                  0.034854 -0.037424  0.065499         0.036702 -0.003956
# Diabetic              0.168553  0.202472  0.053847        -0.057372  0.101518
# PhysicalActivity     -0.100030 -0.150616 -0.097174         0.017487 -0.079455
# DiffWalking       -0.043552  -0.022216  0.103222       0.153064    0.064840
# Sex               -0.010283  -0.015704 -0.069191      -0.009084    0.013434
# AgeCategory        0.044427   0.104953 -0.058108       0.123190    0.263537
# Race               0.050344   0.035889 -0.017975       0.003709    0.134780
# Diabetic          -0.010854   0.000449  0.049827       0.142917    0.032523
# PhysicalActivity   0.024418   0.003849 -0.041526      -0.081827   -0.001328
# GenHealth          1.000000  -0.004163  0.007280      -0.010580    0.018982
# SleepTime         -0.004163   1.000000 -0.048245       0.006238    0.041266
# Asthma             0.007280  -0.048245  1.000000       0.039707   -0.000396
# KidneyDisease     -0.010580   0.006238  0.039707       1.000000    0.061816
# SkinCancer         0.018982   0.041266 -0.000396       0.061816    1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, annot_kws={"size":10}, linewidths=2, linecolor='yellow', cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x="PhysicalHealth", y="MentalHealth", data=df, fit_reg=False, hue="HeartDisease", legend=True)

# %%
sns.lmplot(x="Diabetic", y="PhysicalActivity", data=df, fit_reg=False, hue="HeartDisease", legend=True)

# %% [markdown]
# # Feature Selection & Class Imbalancing

# %%
df.HeartDisease.value_counts()
# Out:
# 0    292422
# 1     27373
# Name: HeartDisease, dtype: int64

# %%
imbalance_value = round(292422/(292422+27373),2)
print(f'{imbalance_value*100}%data is imbalance in target column')
# Out:
# 91.0%data is imbalance in target column

# %%
sns.countplot(df['HeartDisease'], color='green')
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>

# %%
no_HeartDisease = (292422/(292422+27373)) * 100
yes_HeartDisease = (27373/(292422+27373)) * 100

# %%
print(f'According to dataset {yes_HeartDisease}% people has Heart Disease')
print(f'According to dataset {no_HeartDisease}% people has no Heart Disease')
# Out:
# According to dataset 8.559545959130068% people has Heart Disease
# According to dataset 91.44045404086994% people has no Heart Disease

# %% [markdown]
# Let's seperate the dataset first before sampling

# %%
x = df.drop('HeartDisease', axis=1)
y = df['HeartDisease']

# %%
x.head()
# Out:
#      BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0  16.60        1                0       0             3.0          30.0
# 1  20.34        0                0       1             0.0           0.0
# 2  26.58        1                0       0            20.0          30.0
# 3  24.21        0                0       0             0.0           0.0
# 4  23.71        0                0       0            28.0           0.0
#
#    DiffWalking  Sex  AgeCategory  Race  Diabetic  PhysicalActivity  GenHealth  \
# 0            0    0            7     5         2                 1          4
# 1            0    0           12     5         0                 1          4
# 2            0    1            9     5         2                 1          1
# 3            0    0           11     5         0                 0          2
# 4            1    0            4     5         0                 1          4
#
#    SleepTime  Asthma  KidneyDisease  SkinCancer
# 0        5.0       1              0           1
# 1        7.0       0              0           0
# 2        8.0       1              0           0
# 3        6.0       0              0           1
# 4        8.0       0              0           0

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: HeartDisease, dtype: int32

# %% [markdown]
# Let's Over Sampling the dataset first

# %%
from imblearn.combine import SMOTETomek
sm = SMOTETomek()
X_OverSample, y_OverSample = sm.fit_resample(x,y)

# %%
y_OverSample.value_counts()
# Out:
# 0    290125
# 1    290125
# Name: HeartDisease, dtype: int64

# %% [markdown]
# Under Sampling the dataset for making the class value balanced

# %%
from imblearn.under_sampling import NearMiss
nm = NearMiss()
X_UnderSample, y_UnderSample = nm.fit_resample(x, y)

# %%
y_UnderSample.value_counts()
# Out:
# 0    27373
# 1    27373
# Name: HeartDisease, dtype: int64

# %%
print(f'The original Y values is: {y.shape}')
print(f'After Over Sampling the Y values is :{y_OverSample.shape}')
print(f'After Under Sampling the Y values is :{y_UnderSample.shape}')
# Out:
# The original Y values is: (319795,)
# After Over Sampling the Y values is :(580250,)
# After Under Sampling the Y values is :(54746,)

# %% [markdown]
# # Split the data in Train & Test

# %% [markdown]
# Here we pick Under Sampling data and split them. We will also split them in folds for probable future usage.

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score, cross_validate

# %%
x_train, x_test, y_train, y_test = train_test_split(X_UnderSample, y_UnderSample, test_size=.30, random_state=1)

# %%
Kfold = KFold(n_splits=5, shuffle=True, random_state=2)

# %%
fold_number = 1
for train_fold, test_fold, in Kfold.split(X_UnderSample, y_UnderSample):
    print(f'Fold:{fold_number}, Train set:{len(train_fold)}, Test set:{len(test_fold)}')
    fold_number += 1
# Out:
# Fold:1, Train set:43796, Test set:10950
# Fold:2, Train set:43797, Test set:10949
# Fold:3, Train set:43797, Test set:10949
# Fold:4, Train set:43797, Test set:10949
# Fold:5, Train set:43797, Test set:10949

# %% [markdown]
# # Fit the Model with various Algorithms

# %% [markdown]
# Let's fit the data and create a model with various algorithms

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\lenovo\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.4.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.29.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.4)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from sklearn.metrics import accuracy_score

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier(n_neighbors=49)
dtc = DecisionTreeClassifier(min_samples_split=7, random_state=111)
lrc = LogisticRegression(solver='liblinear', penalty= 'l1')
rfc = RandomForestClassifier(n_estimators=31, random_state=111)
abc = AdaBoostClassifier(n_estimators=62, random_state=111)
bc = BaggingClassifier(n_estimators=9, random_state=111)
etc = ExtraTreesClassifier(n_estimators=9, random_state=111)
xgb = XGBClassifier()
ann = tf.keras.models.Sequential()

# %%
clfs = {'SVC':svc, 'KNC':knc, 'DTC':dtc, 'LR': lrc, 'RFC': rfc, 'AdaBoost':abc, 'BGC':bc, 'ETC':etc, 'XGB': xgb }

# %% [markdown]
# Double-click (or enter) to edit

# %%
def train_classifier(clf, x_train, y_train):
    clf.fit(x_train, y_train)

# %%
def predict_labels(clf, x_test):
    return (clf.predict(x_test))

# %%
pred_scores = []
for k,v in clfs.items():
    train_classifier(v, x_train, y_train)
    pred = predict_labels(v, x_test)
    pred_scores.append((k, [accuracy_score(y_test, pred)]))

# %%
model_scores = pd.DataFrame(pred_scores, columns=('Index', 'Score'))
model_scores
# Out:
#       Index                  Score
# 0       SVC  [0.49665124208475403]
# 1       KNC   [0.8441914271797369]
# 2       DTC   [0.8599001461276181]
# 3        LR   [0.8763395031660984]
# 4       RFC   [0.8544812469556746]
# 5  AdaBoost   [0.8920482221139795]
# 6       BGC    [0.860021919142718]
# 7       ETC   [0.8469922065270337]
# 8       XGB   [0.8987457379444715]

# %% [markdown]
# Prepare the ANN for fitting the model

# %%
ann.add(tf.keras.layers.Dense(units=6, activation="relu"))
ann.add(tf.keras.layers.Dense(units=6, activation="relu"))
ann.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
ann.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])

# %% [markdown]
# Fit with ANN

# %%
from tensorflow import keras

# %%
ann.fit(x_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 1198/1198 [==============================] - 3s 2ms/step - loss: 0.5222 - accuracy: 0.8084
# Epoch 2/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.3711 - accuracy: 0.8757
# Epoch 3/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.3327 - accuracy: 0.8809
# Epoch 4/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.3144 - accuracy: 0.8816
# Epoch 5/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.3065 - accuracy: 0.8823
# Epoch 6/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.3012 - accuracy: 0.8836
# Epoch 7/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2971 - accuracy: 0.8835
# Epoch 8/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2954 - accuracy: 0.8837
# Epoch 9/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2945 - accuracy: 0.8840
# Epoch 10/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2920 - accuracy: 0.8855
# Epoch 11/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2903 - accuracy: 0.8847
# Epoch 12/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2901 - accuracy: 0.8846
# Epoch 13/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2889 - accuracy: 0.8849
# Epoch 14/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2884 - accuracy: 0.8848
# Epoch 15/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2871 - accuracy: 0.8854
# Epoch 16/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2874 - accuracy: 0.8850
# Epoch 17/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2862 - accuracy: 0.8854
# Epoch 18/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2868 - accuracy: 0.8846
# Epoch 19/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2853 - accuracy: 0.8854
# Epoch 20/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2846 - accuracy: 0.8859
# Epoch 21/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2841 - accuracy: 0.8853
# Epoch 22/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2844 - accuracy: 0.8853
# Epoch 23/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2836 - accuracy: 0.8854
# Epoch 24/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2839 - accuracy: 0.8859
# Epoch 25/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2832 - accuracy: 0.8855
# Epoch 26/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2837 - accuracy: 0.8852
# Epoch 27/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2826 - accuracy: 0.8852
# Epoch 28/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2819 - accuracy: 0.8861
# Epoch 29/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2809 - accuracy: 0.8869
# Epoch 30/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2805 - accuracy: 0.8861
# Epoch 31/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2814 - accuracy: 0.8855
# Epoch 32/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2803 - accuracy: 0.8867
# Epoch 33/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2809 - accuracy: 0.8857
# Epoch 34/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2812 - accuracy: 0.8866
# Epoch 35/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2803 - accuracy: 0.8861
# Epoch 36/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2799 - accuracy: 0.8866
# Epoch 37/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2798 - accuracy: 0.8861
# Epoch 38/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2805 - accuracy: 0.8858
# Epoch 39/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2802 - accuracy: 0.8861
# Epoch 40/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2801 - accuracy: 0.8858
# Epoch 41/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2800 - accuracy: 0.8857
# Epoch 42/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2798 - accuracy: 0.8862
# Epoch 43/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2806 - accuracy: 0.8863
# Epoch 44/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2795 - accuracy: 0.8862
# Epoch 45/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2797 - accuracy: 0.8865
# Epoch 46/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2791 - accuracy: 0.8866
# Epoch 47/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2793 - accuracy: 0.8864
# Epoch 48/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2796 - accuracy: 0.8872
# Epoch 49/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2792 - accuracy: 0.8866
# Epoch 50/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2794 - accuracy: 0.8869
# Epoch 51/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2790 - accuracy: 0.8865
# Epoch 52/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2791 - accuracy: 0.8873
# Epoch 53/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2791 - accuracy: 0.8865
# Epoch 54/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2803 - accuracy: 0.8866
# Epoch 55/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2787 - accuracy: 0.8878
# Epoch 56/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2787 - accuracy: 0.8870
# Epoch 57/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2786 - accuracy: 0.8872
# Epoch 58/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2783 - accuracy: 0.8873
# Epoch 59/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2783 - accuracy: 0.8878
# Epoch 60/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2777 - accuracy: 0.8876
# Epoch 61/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2776 - accuracy: 0.8878
# Epoch 62/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2773 - accuracy: 0.8877
# Epoch 63/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2772 - accuracy: 0.8873
# Epoch 64/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2772 - accuracy: 0.8887
# Epoch 65/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2765 - accuracy: 0.8886
# Epoch 66/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2761 - accuracy: 0.8885
# Epoch 67/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2761 - accuracy: 0.8886
# Epoch 68/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2759 - accuracy: 0.8882
# Epoch 69/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2753 - accuracy: 0.8889
# Epoch 70/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2751 - accuracy: 0.8886
# Epoch 71/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2753 - accuracy: 0.8877
# Epoch 72/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2745 - accuracy: 0.8882
# Epoch 73/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2750 - accuracy: 0.8878
# Epoch 74/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2750 - accuracy: 0.8879
# Epoch 75/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2746 - accuracy: 0.8888
# Epoch 76/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2748 - accuracy: 0.8889
# Epoch 77/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2742 - accuracy: 0.8887
# Epoch 78/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2735 - accuracy: 0.8888
# Epoch 79/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2742 - accuracy: 0.8884
# Epoch 80/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2738 - accuracy: 0.8888
# Epoch 81/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2740 - accuracy: 0.8894
# Epoch 82/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2741 - accuracy: 0.8894
# Epoch 83/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2734 - accuracy: 0.8886
# Epoch 84/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2731 - accuracy: 0.8891
# Epoch 85/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2723 - accuracy: 0.8895
# Epoch 86/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2726 - accuracy: 0.8894
# Epoch 87/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2728 - accuracy: 0.8895
# Epoch 88/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2735 - accuracy: 0.8889
# Epoch 89/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2728 - accuracy: 0.8886
# Epoch 90/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2727 - accuracy: 0.8893
# Epoch 91/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2727 - accuracy: 0.8887
# Epoch 92/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2730 - accuracy: 0.8890
# Epoch 93/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2727 - accuracy: 0.8895
# Epoch 94/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2728 - accuracy: 0.8904
# Epoch 95/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2722 - accuracy: 0.8891
# Epoch 96/100
# 1198/1198 [==============================] - 2s 2ms/step - loss: 0.2722 - accuracy: 0.8901
# Epoch 97/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2727 - accuracy: 0.8898
# Epoch 98/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2727 - accuracy: 0.8897
# Epoch 99/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2717 - accuracy: 0.8900
# Epoch 100/100
# 1198/1198 [==============================] - 2s 1ms/step - loss: 0.2723 - accuracy: 0.8891

# %% [markdown]
# ANN Accuracy Score

# %%
ann_pred = ann.predict(x_test)
ann_score = accuracy_score(y_test, pred)
ann_score
# Out:
# 514/514 [==============================] - 0s 776us/step
# 0.8987457379444715

# %% [markdown]
# Fit with Kfolds

# %%
kfold_score = cross_val_score(xgb, x_test, y_test, cv=Kfold)
kfold_score
# Out:
# array([0.89041096, 0.89315068, 0.89497717, 0.895586  , 0.88824604])

# %% [markdown]
# Let's fit he model with Another Algorithm

# %%
from sklearn.ensemble import VotingClassifier
eclf = VotingClassifier(estimators=[('Bgc', bc), ('ETC', etc), ('RF', rfc), ('Ada', abc)], voting='soft')
eclf.fit(x_train, y_train)
vt_pred = eclf.predict(x_test)
vt_score = eclf.score(x_test, y_test)
vt_score
# Out:
# 0.8549074525085241

# %% [markdown]
# # Hyper Parameter Tuning

# %% [markdown]
# After fitting the model with many algorithms we found XgBoost scored better. So now we will try to increase our score performing hyper parameter tuning of Xgb.

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix

# %%
params = {
    'max_depth':range(3,10,2),
    'min_child_weight':range(1,6,2),
    'max_depth':[4,5,6,8,10],
    'gamma':[i/10.0 for i in range(0,5)],
    'subsample':[i/10.0 for i in range(6, 10)],
    'colsample_bytree':[i/10.0 for i in range(6, 10)],
    'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]
}

print(params)
# Out:
# {'max_depth': [4, 5, 6, 8, 10], 'min_child_weight': range(1, 6, 2), 'gamma': [0.0, 0.1, 0.2, 0.3, 0.4], 'subsample': [0.6, 0.7, 0.8, 0.9], 'colsample_bytree': [0.6, 0.7, 0.8, 0.9], 'reg_alpha': [1e-05, 0.01, 0.1, 1, 100]}

# %%
tuning_xgb_clf = XGBClassifier()
tuning_xgb_rcv = RandomizedSearchCV(tuning_xgb_clf, params, n_iter=200, cv=3)
tuning_xgb_rcv.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=100, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            predictor=None, random_state=None, ...),
#                    n_iter=200,
#                    param_distributions={'colsample_bytree': [0.6, 0.7, 0.8,
#                                                              0.9],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'max_depth': [4, 5, 6, 8, 10],
#                                         'min_child_weight': range(1, 6, 2),
#                                         'reg_alpha': [1e-05, 0.01, 0.1, 1, 100],
#                                         'subsample': [0.6, 0.7, 0.8, 0.9]})

# %%
tuning_xgb_rcv.cv_results_
# Out:
# {'mean_fit_time': array([0.45703189, 0.8038938 , 0.36591919, 0.58819405, 0.51821955,
#         0.46309519, 0.53929774, 0.4073329 , 0.91823387, 0.56402644,
#         0.55035011, 0.77157672, 0.55008896, 0.4228545 , 0.95575269,
#         0.68396942, 0.83586526, 0.73780505, 0.91372983, 0.51779977,
#         1.05119006, 0.46943506, 1.3391215 , 0.63201062, 0.5816807 ,
#         0.79523214, 0.51350729, 0.66134246, 0.53956588, 1.25784858,
#         0.69615142, 0.62456981, 0.55542699, 1.08203832, 0.65865366,
#         0.76882299, 0.96523499, 1.48156309, 0.93838104, 0.67658981,
#         1.03827063, 0.8823053 , 1.28627936, 1.84527993, 1.44703007,
#         0.71882852, 1.66544541, 0.93919675, 0.97395142, 0.88619184,
#         0.79050183, 0.90342887, 1.43738619, 0.64712461, 1.28955738,
#         0.87294849, 0.65477729, 0.62613416, 0.66643445, 0.89379636,
#         0.92488654, 0.60735337, 1.37848067, 1.07514612, 1.09808906,
#         1.05553905, 1.00957251, 0.85494741, 1.33914884, 1.12809038,
#         1.34022832, 0.47301205, 0.50828155, 1.05980388, 0.58259948,
#         0.60408815, 1.30654995, 0.53460757, 0.82853071, 0.89965137,
#         0.86025437, 0.64879251, 0.56801351, 0.4926943 , 0.72503281,
#         0.74972709, 1.55852874, 0.94397155, 0.63060784, 0.74431793,
#         0.96661536, 0.82883581, 0.59851114, 0.7312932 , 1.42420093,
#         0.83386167, 1.01804058, 0.63673655, 0.58410486, 0.80169535,
#         1.21867641, 1.31177004, 0.58556859, 0.65550963, 1.01124827,
#         0.64057692, 0.77307661, 1.23263446, 0.88777709, 0.96301754,
#         0.754064  , 0.98128327, 1.22284381, 1.01136621, 0.99636499,
#         0.5561227 , 0.64999684, 0.52671758, 0.63990561, 0.66821154,
#         0.76872381, 1.05216344, 1.02834805, 0.71404854, 1.14428902,
#         0.53305658, 0.84217183, 1.25818602, 1.46545537, 0.64333963,
#         0.47602216, 1.30969795, 0.54470015, 1.03627253, 1.05268407,
#         0.52912211, 0.64867528, 0.53275863, 0.7155567 , 0.52414886,
#         0.48001194, 0.75229716, 1.07391445, 0.80860114, 0.76369262,
#         0.68363372, 0.50187039, 0.78471732, 0.98634561, 0.68396409,
#         0.63683923, 0.68654911, 0.60308838, 0.76387485, 1.37719123,
#                     0.8, 0.7, 0.8, 0.8, 0.7, 0.7, 0.7, 0.7, 0.9, 0.9, 0.6,
#                     0.7, 0.6, 0.8, 0.7, 0.7, 0.9, 0.9, 0.6, 0.8, 0.7, 0.6,
#                     0.8, 0.8, 0.6, 0.6, 0.9, 0.8, 0.9, 0.8, 0.8, 0.8, 0.6,
#                     0.7, 0.9, 0.7, 0.7, 0.6, 0.8, 0.6, 0.8, 0.6, 0.6, 0.8,
#                     0.6, 0.9, 0.9, 0.8, 0.7, 0.9, 0.9, 0.8, 0.7, 0.8, 0.6,
#                     0.9, 0.8, 0.6, 0.9, 0.7, 0.7, 0.7, 0.9, 0.9, 0.7, 0.8,
#                     0.9, 0.8],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_reg_alpha': masked_array(data=[1, 0.01, 100, 1e-05, 0.1, 1, 1, 100, 1, 0.01, 1e-05,
#                     0.01, 0.1, 0.01, 0.01, 1e-05, 0.1, 1e-05, 1, 100,
#                     1e-05, 100, 0.01, 0.1, 1, 0.01, 100, 0.01, 100, 0.01,
#                     1, 1e-05, 100, 1, 1e-05, 0.01, 0.01, 1, 1e-05, 1e-05,
#                     0.1, 0.01, 1e-05, 0.01, 0.1, 0.1, 1e-05, 1e-05, 0.1,
#                     0.01, 0.01, 0.1, 0.01, 100, 1e-05, 1, 100, 100, 100,
#                     1e-05, 1, 100, 1, 0.1, 1e-05, 1e-05, 1, 1e-05, 0.1,
#                     0.01, 1e-05, 100, 100, 1e-05, 100, 0.1, 0.1, 100,
#                     1e-05, 1, 1e-05, 1, 100, 100, 1, 0.01, 1, 0.01, 100,
#                     0.01, 1, 0.01, 100, 0.1, 1e-05, 0.1, 0.1, 0.1, 100,
#                     0.01, 0.1, 1e-05, 0.1, 0.01, 0.1, 0.1, 1e-05, 0.01,
#                     0.01, 1e-05, 0.01, 1e-05, 0.1, 0.01, 0.01, 100, 1e-05,
#                     100, 0.1, 1e-05, 1, 1e-05, 0.01, 1e-05, 0.01, 100,
#                     1e-05, 0.1, 0.1, 0.1, 100, 0.01, 100, 1, 1e-05, 100,
#                     0.01, 100, 0.1, 100, 100, 0.1, 0.01, 1e-05, 0.1, 0.01,
#                     100, 1e-05, 1e-05, 1e-05, 0.01, 1, 100, 1e-05, 0.01,
#                     1e-05, 0.01, 100, 1e-05, 1, 0.1, 0.01, 1, 1e-05, 100,
#                     100, 0.1, 0.1, 1, 100, 0.01, 1e-05, 1, 100, 1e-05, 100,
#                     1e-05, 0.1, 1e-05, 1, 100, 1, 1, 0.1, 0.01, 0.01, 1,
#                     100, 0.01, 1e-05, 1e-05, 1, 100, 1e-05, 100, 1, 1, 1,
#                     0.01, 1e-05],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_weight': masked_array(data=[5, 3, 1, 5, 3, 1, 3, 3, 3, 1, 1, 3, 5, 3, 5, 1, 3, 1,
#                     3, 5, 3, 1, 5, 5, 3, 5, 5, 1, 1, 1, 5, 5, 5, 5, 5, 1,
#                     1, 1, 5, 3, 3, 3, 1, 1, 5, 3, 1, 3, 1, 3, 3, 1, 3, 1,
#                     3, 3, 1, 3, 5, 3, 1, 3, 1, 5, 5, 5, 1, 3, 3, 1, 5, 5,
#                     3, 3, 3, 3, 3, 3, 1, 5, 5, 3, 3, 1, 1, 3, 3, 1, 5, 5,
#                     3, 5, 5, 3, 1, 1, 5, 3, 5, 5, 5, 1, 3, 3, 3, 5, 5, 5,
#                     5, 5, 3, 1, 5, 5, 1, 3, 5, 1, 3, 3, 1, 3, 3, 5, 1, 3,
#                     1, 5, 3, 5, 3, 5, 1, 5, 5, 1, 1, 1, 5, 3, 5, 3, 5, 3,
#                     1, 1, 1, 1, 3, 5, 3, 3, 1, 3, 5, 1, 5, 3, 5, 1, 1, 3,
#                     5, 3, 1, 3, 3, 5, 1, 1, 3, 3, 5, 5, 1, 1, 1, 5, 3, 5,
#                     1, 1, 5, 5, 3, 3, 5, 3, 3, 5, 5, 3, 5, 1, 3, 3, 3, 3,
#                     1, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[4, 8, 5, 6, 5, 4, 6, 10, 10, 6, 6, 8, 5, 4, 10, 6, 5,
#                     4, 6, 5, 8, 4, 10, 4, 4, 5, 6, 4, 10, 10, 5, 4, 10, 6,
#                     4, 5, 6, 10, 5, 5, 8, 6, 8, 8, 10, 4, 8, 5, 6, 4, 4, 6,
#                     10, 10, 8, 5, 8, 4, 6, 6, 6, 6, 10, 8, 8, 6, 6, 4, 10,
#                     8, 10, 4, 6, 8, 10, 4, 10, 8, 6, 6, 5, 4, 10, 5, 5, 5,
#                     10, 6, 10, 5, 6, 5, 8, 5, 10, 5, 8, 4, 10, 6, 8, 10, 4,
#                     4, 8, 4, 6, 10, 6, 8, 5, 8, 10, 8, 8, 10, 4, 8, 4, 5,
#                     6, 8, 8, 5, 8, 8, 6, 10, 10, 4, 4, 10, 8, 8, 8, 8, 4,
#                     6, 5, 6, 5, 6, 8, 6, 5, 5, 6, 5, 8, 5, 4, 5, 6, 4, 10,
#                     8, 8, 6, 4, 6, 6, 4, 5, 10, 8, 8, 10, 4, 8, 6, 6, 10,
#                     10, 10, 8, 10, 10, 6, 10, 10, 6, 10, 6, 4, 4, 8, 10, 8,
#                     6, 6, 5, 5, 4, 6, 8, 5, 8, 4, 6, 6],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_gamma': masked_array(data=[0.2, 0.0, 0.0, 0.3, 0.4, 0.0, 0.1, 0.2, 0.2, 0.4, 0.4,
#                     0.1, 0.2, 0.1, 0.3, 0.0, 0.0, 0.4, 0.3, 0.2, 0.3, 0.1,
#                     0.2, 0.0, 0.1, 0.0, 0.1, 0.2, 0.1, 0.0, 0.1, 0.4, 0.1,
#                     0.0, 0.2, 0.3, 0.2, 0.4, 0.4, 0.3, 0.3, 0.2, 0.4, 0.2,
#                     0.2, 0.4, 0.1, 0.0, 0.2, 0.2, 0.2, 0.3, 0.3, 0.1, 0.0,
#                     0.3, 0.3, 0.1, 0.1, 0.3, 0.1, 0.3, 0.2, 0.0, 0.2, 0.3,
#                     0.2, 0.4, 0.4, 0.2, 0.3, 0.4, 0.0, 0.2, 0.4, 0.2, 0.0,
#                     0.3, 0.0, 0.4, 0.2, 0.0, 0.4, 0.2, 0.0, 0.4, 0.1, 0.2,
#                     0.2, 0.2, 0.4, 0.1, 0.4, 0.3, 0.4, 0.3, 0.1, 0.3, 0.3,
#         2.04539616e-03, 1.15112703e-03, 1.11690071e-03, 8.34213630e-04,
#         1.51033830e-03, 1.07210681e-03, 2.01554945e-03, 2.06659254e-03,
#         1.59966934e-03, 6.89413121e-04, 1.35038349e-03, 1.82923461e-03,
#         9.41580218e-04, 1.31668241e-03, 1.56611514e-03, 1.50310744e-03,
#         1.92853569e-03, 2.10737698e-03, 2.02364135e-03, 9.61616083e-04,
#         1.18378960e-03, 2.51999419e-03, 1.89649207e-03, 1.38915836e-03,
#         6.89413121e-04, 7.74972204e-04, 1.93276804e-03, 7.35295799e-04,
#         8.30942191e-04, 1.61871118e-03, 1.92853569e-03, 1.33466018e-03,
#         5.85823922e-04, 2.42918827e-03, 1.06381802e-03, 1.78171390e-03,
#         1.43828754e-03, 7.99195910e-04, 1.38277139e-03, 1.31150064e-03]),
#  'rank_test_score': array([  7, 107, 180,  69,  44,  15,  64, 159, 144,  38,  53, 106,  35,
#          24, 137,  74,  75,  13,  93, 199, 115, 185, 140,  26,  29,  61,
#         183,  30, 161, 163,  50,  32, 171,  83,   9,  39,  85, 165,  85,
#          50, 125,  76, 139, 142, 120,   7, 147,  33,  88,  23,  19,  48,
#         126, 172, 116,  30, 179, 187, 182,  82,  90, 196, 150, 122, 104,
#          96,  67,  19, 151, 137, 129, 188, 191, 108, 152,  22, 143, 166,
#          57,  66,  87,   1, 155, 198,  39,  73, 153, 105, 175,  48,  97,
#          44, 177,  37, 162,  59, 103,  25, 157,  41, 117, 164,  11,   5,
#          99,  33,  60, 127,  94,  98,  57, 111, 124, 100, 118, 174,  27,
#         168,  14,  62,  78, 113, 123,  43, 156, 178,  95, 134, 148,   4,
#         200, 146, 170, 102, 109, 173,  12, 189,  41, 192, 181,  80, 114,
#          56,  65,  46, 186,  63, 101,  47,   6,  21, 192,  35, 136, 133,
#         112, 197,  16,  71,  80,   2,  16, 140, 184, 176, 144,  55, 130,
#         195,  67, 132, 118, 159, 128, 154, 169,  72, 149, 131, 190, 135,
#          70,   3,  28, 121, 110, 158,  89,  90,  50,  77, 194,  79, 167,
#          18,  92,  10,  53,  84])}

# %%
best_params = tuning_xgb_rcv.best_params_
best_params
# Out:
# {'subsample': 0.7,
#  'reg_alpha': 1,
#  'min_child_weight': 3,
#  'max_depth': 4,
#  'gamma': 0.0,
#  'colsample_bytree': 0.7}

# %%
tuning_xgb_rcv.best_score_
# Out:
# 0.8950994206982935

# %%
tune_clf = tuning_xgb_rcv.best_estimator_
tune_clf.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.0, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
tune_score = tune_clf.score(x_test, y_test)
tune_score
# Out:
# 0.899171943497321

# %%
tune_pred = tune_clf.predict(x_test)
cm = confusion_matrix(tune_pred, y_test)
cm
# Out:
# array([[7815, 1204],
#        [ 452, 6953]], dtype=int64)

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
# Out:
# <AxesSubplot:>

# %%
tp, fn, fp, tn = confusion_matrix(y_test, tune_pred).reshape(-1)
print('This is True positive: ', tp)
print('This is True Negative: ', tn)
print('This is False Positive: ', fp)
print('This is False Negative: ', fn)
# Out:
# This is True positive:  7815
# This is True Negative:  6953
# This is False Positive:  1204
# This is False Negative:  452
